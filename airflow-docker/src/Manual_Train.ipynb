# %%
import pandas as pd
import numpy as np
import datetime

# %%
from model_management.Train import main_train

# %%
params_dict = {
    'meta_path': '../../trained_model_parameters/model_meta_2024-08-30/', 
    'data_path': '../../historical/data/', 
    'test_size': 0.001,
    'test_last_fold': False,
    'apply_night_peak': False,
    'start_date': '2023-08-01',
    'end_date': '2200-12-31'
}
train_model_main_path = '../../trained_model_parameters/models_tobe_evaluated/'
train_stop_date = datetime.datetime.strptime('2024-08-17', '%Y-%m-%d').date()
preserved_days = (datetime.datetime.now().date() - train_stop_date) / datetime.timedelta(days=1) - 1

# %%
main_train(params=params_dict, train_model_main_path=train_model_main_path, preserved_days=preserved_days,
           apply_night_peak=False, remove_night_peak_samples=True)
main_train(params=params_dict, train_model_main_path=train_model_main_path, preserved_days=preserved_days,
           apply_night_peak=True, remove_night_peak_samples=True)
main_train(params=params_dict, train_model_main_path=train_model_main_path, preserved_days=preserved_days,
           apply_night_peak=False, remove_night_peak_samples=False)
# Out:
# ../../trained_model_parameters/models_tobe_evaluated/model_2024-08-17/
# 夜尖峰 訓練中.
# (1/6) FCN
# (2/6) LogisticRegression
# (3/6) RandomForest
# (4/6) XGBoost
# (5/6) LightGBM
# (6/6) SVC
# 太陽能 訓練中.
# (1/5) LinearRegression
# (2/5) FCN
# (3/5) RandomForest
# (4/5) XGBoost
# (5/5) LightGBM
# 尖峰負載 訓練中.
# (1/4) FCN
# (2/4) XGBoost
# (3/4) LightGBM
# (4/4) SVR
# 日照率 訓練中.
# (1/3) XGBoost
# (2/3) SVR
# (3/3) NuSVR
# 最低氣溫 訓練中.
# (1/4) LinearRegression
# (2/4) RandomForest
# (3/4) XGBoost
# (4/4) SVR
# 最高氣溫 訓練中.
# (1/4) FCN
# (2/4) SVR
# (3/4) NuSVR
# (4/4) LightGBM
# 氣溫 訓練中.
# (1/3) RandomForest
# (2/3) XGBoost
# (3/3) NuSVR
# 風力 訓練中.
# (1/6) FCN
# (2/6) RandomForest
# (3/6) XGBoost
# (4/6) LightGBM
# (5/6) SVR
# (6/6) NuSVR
# 風速 訓練中.
# (1/2) RandomForest
# (2/2) SVR
# ../../trained_model_parameters/models_tobe_evaluated/model_2024-08-17_NP/
# 夜尖峰 訓練中.
# (1/6) FCN
# (2/6) LogisticRegression
# (3/6) RandomForest
# (4/6) XGBoost
# (5/6) LightGBM
# (6/6) SVC
# 太陽能 訓練中.
# (1/5) LinearRegression
# (2/5) FCN
# (3/5) RandomForest
# (4/5) XGBoost
# (5/5) LightGBM
# (1/6) FCN
# (2/6) LogisticRegression
# (3/6) RandomForest
# (4/6) XGBoost
# (5/6) LightGBM
# (6/6) SVC
# 尖峰負載 訓練中.
# (1/4) FCN
# (2/4) XGBoost
# (3/4) LightGBM
# (4/4) SVR
# 日照率 訓練中.
# (1/3) XGBoost
# (2/3) SVR
# (3/3) NuSVR
# 最低氣溫 訓練中.
# (1/4) LinearRegression
# (2/4) RandomForest
# (3/4) XGBoost
# (4/4) SVR
# 最高氣溫 訓練中.
# (1/4) FCN
# (2/4) SVR
# (3/4) NuSVR
# (4/4) LightGBM
# 氣溫 訓練中.
# (1/3) RandomForest
# (2/3) XGBoost
# (3/3) NuSVR
# 風力 訓練中.
# (1/6) FCN
# (2/6) RandomForest
# (3/6) XGBoost
# (4/6) LightGBM
# (5/6) SVR
# (6/6) NuSVR
# 風速 訓練中.
# (1/2) RandomForest
# (2/2) SVR
# ../../trained_model_parameters/models_tobe_evaluated/model_2024-08-17_PNPS/
# 夜尖峰 訓練中.
# (1/6) FCN
# (2/6) LogisticRegression
# (3/6) RandomForest
# (4/6) XGBoost
# (5/6) LightGBM
# (6/6) SVC
# 太陽能 訓練中.
# (1/5) LinearRegression
# (2/5) FCN
# (3/5) RandomForest
# (4/5) XGBoost
# (5/5) LightGBM
# 尖峰負載 訓練中.
# (1/4) FCN
# (2/4) XGBoost
# (3/4) LightGBM
# (4/4) SVR
# 日照率 訓練中.
# (1/3) XGBoost
# (2/3) SVR
# (3/3) NuSVR
# 最低氣溫 訓練中.
# (1/4) LinearRegression
# (2/4) RandomForest
# (3/4) XGBoost
# (4/4) SVR
# 最高氣溫 訓練中.
# (1/4) FCN
# (2/4) SVR
# (3/4) NuSVR
# (4/4) LightGBM
# 氣溫 訓練中.
# (1/3) RandomForest
# (2/3) XGBoost
# (3/3) NuSVR
# 風力 訓練中.
# (1/6) FCN
# (2/6) RandomForest
# (3/6) XGBoost
# (4/6) LightGBM
# (5/6) SVR
# (6/6) NuSVR
# 風速 訓練中.
# (1/2) RandomForest
# (2/2) SVR
